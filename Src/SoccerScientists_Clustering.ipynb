# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
import sklearn
import seaborn as sns
import datetime

# %% [markdown]
# ### Argentina

# %%
#Reading in the datasets
Ar_df = pd.read_csv("https://raw.githubusercontent.com/Brianc482/731_Group_Project/main/Data/Argentina_cleaned.csv")
Ar_df.head()
# Out:
#          Name  Age Nationality  Overall  Potential        Value      Wage  \
# 0    L. Messi   31   Argentina       94         94  110500000.0  565000.0
# 1   P. Dybala   24   Argentina       89         94   89000000.0  205000.0
# 2   S. Agüero   30   Argentina       89         89   64500000.0  300000.0
# 3  G. Higuaín   30   Argentina       88         88   57000000.0  245000.0
# 4   M. Icardi   25   Argentina       87         90   64500000.0  130000.0
#
#    Special Preferred Foot  International Reputation  ...  Composure  Marking  \
# 0     2202           Left                       5.0  ...       96.0     33.0
# 1     2092           Left                       3.0  ...       84.0     23.0
# 2     2107          Right                       4.0  ...       90.0     30.0
# 3     1965          Right                       4.0  ...       86.0     35.0
# 4     1940          Right                       3.0  ...       85.0     45.0
#
#   StandingTackle SlidingTackle GKDiving GKHandling  GKKicking GKPositioning  \
# 0           28.0          26.0      6.0       11.0       15.0          14.0
# 1           20.0          20.0      5.0        4.0        4.0           5.0
# 2           20.0          12.0     13.0       15.0        6.0          11.0
# 3           22.0          18.0      5.0       12.0        7.0           5.0
# 4           24.0          20.0     13.0        9.0        5.0           7.0
#
#   GKReflexes Release Clause
# 0        8.0        €226.5M
# 1        8.0        €153.5M
# 2       14.0        €119.3M
# 3       10.0              0
# 4        9.0        €114.5M
#
# [5 rows x 83 columns]

# %%
#Describing the dataset
Ar_df.describe()
# Out:
#               Age     Overall   Potential         Value           Wage  \
# count  937.000000  937.000000  937.000000  9.360000e+02     936.000000
# mean    26.205977   68.572038   73.210245  3.080299e+06   11514.957265
# std      5.057284    6.166440    5.309601  6.873466e+06   27211.427896
# min     16.000000   51.000000   57.000000  2.000000e+04    1000.000000
# 25%     22.000000   64.000000   69.000000  4.750000e+05    2000.000000
# 50%     26.000000   69.000000   73.000000  1.100000e+06    6000.000000
# 75%     30.000000   73.000000   77.000000  3.200000e+06   12000.000000
# max     41.000000   94.000000   94.000000  1.105000e+08  565000.000000
#
#            Special  International Reputation   Weak Foot  Skill Moves  \
# count   937.000000                937.000000  937.000000   937.000000
# mean   1639.410886                  1.132337    2.867663     2.451441
# std     265.560528                  0.445287    0.605874     0.799332
# min     793.000000                  0.000000    0.000000     0.000000
# 25%    1500.000000                  1.000000    3.000000     2.000000
# 50%    1677.000000                  1.000000    3.000000     2.000000
# 75%    1829.000000                  1.000000    3.000000     3.000000
# max    2265.000000                  5.000000    5.000000     5.000000
#
#        Jersey Number  ...   Penalties   Composure     Marking  StandingTackle  \
# count     937.000000  ...  937.000000  937.000000  937.000000      937.000000
# mean       16.248666  ...   51.786553   60.388474   48.225187       47.918890
# std        10.585784  ...   15.488116   11.475848   20.150382       22.256993
# min         0.000000  ...    0.000000    0.000000    0.000000        0.000000
# 25%         8.000000  ...   43.000000   53.000000   30.000000       26.000000
# 50%        15.000000  ...   53.000000   61.000000   54.000000       53.000000
# 75%        23.000000  ...   63.000000   68.000000   66.000000       68.000000
# max        88.000000  ...   90.000000   96.000000   85.000000       85.000000
#
#        SlidingTackle    GKDiving  GKHandling   GKKicking  GKPositioning  \
# count     937.000000  937.000000  937.000000  937.000000     937.000000
# mean       46.291355   16.292423   16.268943   16.267876      16.468517
# std        21.785656   17.849857   17.073879   16.999804      17.579105
# min         0.000000    0.000000    0.000000    0.000000       0.000000
# 25%        24.000000    8.000000    8.000000    8.000000       8.000000
# 50%        53.000000   11.000000   11.000000   11.000000      11.000000
# 75%        66.000000   14.000000   14.000000   14.000000      14.000000
# max        84.000000   83.000000   79.000000   84.000000      82.000000
#
#        GKReflexes
# count  937.000000
# mean    16.414088
# std     18.182695
# min      0.000000
# 25%      8.000000
# 50%     11.000000
# 75%     14.000000
# max     84.000000
#
# [8 rows x 72 columns]

# %%
#Extracting numeric columns from the dataset
Ar_df.describe().columns
# Out:
# Index(['Age', 'Overall', 'Potential', 'Value', 'Wage', 'Special',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes'],
#       dtype='object')

# %%
Ar_df = Ar_df[['Name','Age', 'Overall', 'Potential', 'Value', 'Wage', 'Special',
       'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number',
       'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']]

# %%
Ar_df.head()
# Out:
#          Name  Age  Overall  Potential        Value      Wage  Special  \
# 0    L. Messi   31       94         94  110500000.0  565000.0     2202
# 1   P. Dybala   24       89         94   89000000.0  205000.0     2092
# 2   S. Agüero   30       89         89   64500000.0  300000.0     2107
# 3  G. Higuaín   30       88         88   57000000.0  245000.0     1965
# 4   M. Icardi   25       87         90   64500000.0  130000.0     1940
#
#    International Reputation  Weak Foot  Skill Moves  ...  Penalties  \
# 0                       5.0        4.0          4.0  ...       75.0
# 1                       3.0        3.0          4.0  ...       86.0
# 2                       4.0        4.0          4.0  ...       83.0
# 3                       4.0        4.0          3.0  ...       70.0
# 4                       3.0        4.0          3.0  ...       82.0
#
#    Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0       96.0     33.0            28.0           26.0       6.0        11.0
# 1       84.0     23.0            20.0           20.0       5.0         4.0
# 2       90.0     30.0            20.0           12.0      13.0        15.0
# 3       86.0     35.0            22.0           18.0       5.0        12.0
# 4       85.0     45.0            24.0           20.0      13.0         9.0
#
#    GKKicking  GKPositioning  GKReflexes
# 0       15.0           14.0         8.0
# 1        4.0            5.0         8.0
# 2        6.0           11.0        14.0
# 3        7.0            5.0        10.0
# 4        5.0            7.0         9.0
#
# [5 rows x 45 columns]

# %%
#Selecting players with an overall score above 80
Ar_df = Ar_df[Ar_df.Overall > 80]

# %%
#Create a separate column for names
player_names= names = Ar_df.Name.tolist() # saving names for later

Ar_df = Ar_df.drop(['Name'], axis = 1) # drop the name column so that the dataframe consists of only numeric values
Ar_df.head()
# Out:
#    Age  Overall  Potential        Value      Wage  Special  \
# 0   31       94         94  110500000.0  565000.0     2202
# 1   24       89         94   89000000.0  205000.0     2092
# 2   30       89         89   64500000.0  300000.0     2107
# 3   30       88         88   57000000.0  245000.0     1965
# 4   25       87         90   64500000.0  130000.0     1940
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  ...  \
# 0                       5.0        4.0          4.0           10.0  ...
# 1                       3.0        3.0          4.0           21.0  ...
# 2                       4.0        4.0          4.0           10.0  ...
# 3                       4.0        4.0          3.0            9.0  ...
# 4                       3.0        4.0          3.0            9.0  ...
#
#    Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0       75.0       96.0     33.0            28.0           26.0       6.0
# 1       86.0       84.0     23.0            20.0           20.0       5.0
# 2       83.0       90.0     30.0            20.0           12.0      13.0
# 3       70.0       86.0     35.0            22.0           18.0       5.0
# 4       82.0       85.0     45.0            24.0           20.0      13.0
#
#    GKHandling  GKKicking  GKPositioning  GKReflexes
# 0        11.0       15.0           14.0         8.0
# 1         4.0        4.0            5.0         8.0
# 2        15.0        6.0           11.0        14.0
# 3        12.0        7.0            5.0        10.0
# 4         9.0        5.0            7.0         9.0
#
# [5 rows x 44 columns]

# %% [markdown]
# __K-Means__

# %%
#Normalizing the dataset

from sklearn import preprocessing

x = Ar_df.values
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
X_norm = pd.DataFrame(x_scaled)

# %%
#Combined the many columns existing into 2 columns for comparing


from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
reduced = pd.DataFrame(pca.fit_transform(X_norm))
n=pca.explained_variance_ratio_
pca.explained_variance_ratio_
# Out:
# array([0.4308, 0.143 ])

# %%
# Created 4 clusters for analysis
y= n[0:2]
kmeans = KMeans(n_clusters=4)
kmeans = kmeans.fit(reduced)
labels = kmeans.predict(reduced)
centroid = kmeans.cluster_centers_
clusters = kmeans.labels_.tolist()

# %%
reduced['cluster'] = clusters
reduced['name'] = player_names
reduced.columns = ['x', 'y', 'cluster', 'name']
reduced.head()
# Out:
#           x         y  cluster        name
# 0 -1.943894  0.579224        2    L. Messi
# 1 -1.499782  0.409433        2   P. Dybala
# 2 -1.210329  0.762886        2   S. Agüero
# 3 -0.809109  1.200615        2  G. Higuaín
# 4 -0.407126  1.503831        2   M. Icardi

# %%
#Plotting

sns.set(style="white")

ax = sns.lmplot(x="x", y="y", hue='cluster', data = reduced, legend=False,
                   fit_reg=False, size = 10, scatter_kws={"s": 250})

texts = []
for x, y, s in zip(reduced.x, reduced.y, reduced.name):
    texts.append(plt.text(x, y, s))

ax.set(ylim=(-2, 2))
plt.tick_params(labelsize=15)
plt.xlabel("PC 1", fontsize = 20)
plt.ylabel("PC 2", fontsize = 20)

plt.show()
# Out:
# C:\Users\shrik\anaconda3\lib\site-packages\seaborn\regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# __Hierarchical Clustering__

# %%
import scipy
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
np.set_printoptions (precision=4, suppress=True)
plt.figure(figsize=(10,3))
# %matplotlib inline

# %%
plt.figure(figsize=(10,14))
plt.title('Hierarchical Clustering Dendrogram with Average Linkage')

dendrogram = dendrogram(linkage(X_norm, method="average"), labels= names, leaf_font_size = 13, orientation='right')

# %% [markdown]
# ### Brazil

# %%
#Reading in the datasets
Br_df = pd.read_csv("https://raw.githubusercontent.com/Brianc482/731_Group_Project/main/Data/Brazil_cleaned.csv")
Br_df.head()
# Out:
#            Name  Age Nationality  Overall  Potential        Value      Wage  \
# 0     Neymar Jr   26      Brazil       92         93  118500000.0  290000.0
# 1      Casemiro   26      Brazil       88         90   59500000.0  285000.0
# 2      Coutinho   26      Brazil       88         89   69500000.0  340000.0
# 3       Marcelo   30      Brazil       88         88   43000000.0  285000.0
# 4  Thiago Silva   33      Brazil       88         88   24000000.0  165000.0
#
#    Special Preferred Foot  International Reputation  ...  Composure  Marking  \
# 0     2143          Right                       5.0  ...       94.0     27.0
# 1     2170          Right                       3.0  ...       84.0     88.0
# 2     2175          Right                       3.0  ...       85.0     55.0
# 3     2279           Left                       4.0  ...       86.0     71.0
# 4     2077          Right                       4.0  ...       81.0     88.0
#
#   StandingTackle SlidingTackle GKDiving GKHandling  GKKicking GKPositioning  \
# 0           24.0          33.0      9.0        9.0       15.0          15.0
# 1           90.0          87.0     13.0       14.0       16.0          12.0
# 2           54.0          47.0     12.0        7.0        9.0          14.0
# 3           85.0          86.0     12.0        5.0        5.0           5.0
# 4           89.0          85.0      9.0       12.0        5.0           9.0
#
#   GKReflexes Release Clause
# 0       11.0        €228.1M
# 1       12.0        €126.4M
# 2        6.0        €147.7M
# 3        9.0         €88.2M
# 4       10.0         €44.4M
#
# [5 rows x 83 columns]

# %%
#Describing the dataset
Br_df.describe()
# Out:
#               Age     Overall   Potential         Value           Wage  \
# count  827.000000  827.000000  827.000000  8.260000e+02     827.000000
# mean    27.625151   71.251511   73.351874  4.608202e+06   17778.718259
# std      4.243753    5.590515    5.785576  8.317288e+06   31885.397567
# min     17.000000   48.000000   59.000000  6.000000e+04    1000.000000
# 25%     25.000000   68.000000   69.000000  7.250000e+05    4000.000000
# 50%     27.000000   71.000000   73.000000  1.900000e+06   10000.000000
# 75%     30.000000   74.000000   77.000000  5.000000e+06   18000.000000
# max     40.000000   92.000000   93.000000  1.185000e+08  340000.000000
#
#            Special  International Reputation   Weak Foot  Skill Moves  \
# count   827.000000                827.000000  827.000000   827.000000
# mean   1712.134220                  1.160822    2.938331     2.627570
# std     256.012423                  0.508536    0.762193     0.857449
# min     857.000000                  0.000000    0.000000     0.000000
# 25%    1593.500000                  1.000000    2.000000     2.000000
# 50%    1759.000000                  1.000000    3.000000     3.000000
# 75%    1878.000000                  1.000000    3.000000     3.000000
# max    2279.000000                  5.000000    5.000000     5.000000
#
#        Jersey Number  ...   Penalties   Composure     Marking  StandingTackle  \
# count     827.000000  ...  827.000000  827.000000  827.000000      827.000000
# mean       18.637243  ...   55.166868   65.083434   49.102781       51.160822
# std        20.563466  ...   15.748899   10.521237   23.701030       23.589857
# min         0.000000  ...    0.000000    0.000000    0.000000        0.000000
# 25%         7.000000  ...   47.000000   59.000000   26.000000       28.000000
# 50%        12.000000  ...   58.000000   66.000000   56.000000       60.000000
# 75%        21.000000  ...   67.000000   72.000000   70.000000       72.000000
# max        99.000000  ...   91.000000   94.000000   90.000000       90.000000
#
#        SlidingTackle    GKDiving  GKHandling   GKKicking  GKPositioning  \
# count     827.000000  827.000000  827.000000  827.000000     827.000000
# mean       48.863362   15.807739   15.402660   15.471584      15.351874
# std        23.243254   16.990256   16.187047   15.822643      16.613853
# min         0.000000    0.000000    0.000000    0.000000       0.000000
# 25%        26.000000    8.000000    8.000000    8.000000       8.000000
# 50%        56.000000   11.000000   11.000000   11.000000      11.000000
# 75%        70.000000   14.000000   14.000000   14.000000      14.000000
# max        87.000000   85.000000   84.000000   91.000000      84.000000
#
#        GKReflexes
# count  827.000000
# mean    16.037485
# std     17.267089
# min      0.000000
# 25%      9.000000
# 50%     11.000000
# 75%     14.000000
# max     88.000000
#
# [8 rows x 72 columns]

# %%
#Extracting numeric columns from the dataset
Br_df.describe().columns
# Out:
# Index(['Age', 'Overall', 'Potential', 'Value', 'Wage', 'Special',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes'],
#       dtype='object')

# %%
Br_df = Br_df[['Name','Age', 'Overall', 'Potential', 'Value', 'Wage', 'Special',
       'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number',
       'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']]

# %%
Br_df.head()
# Out:
#            Name  Age  Overall  Potential        Value      Wage  Special  \
# 0     Neymar Jr   26       92         93  118500000.0  290000.0     2143
# 1      Casemiro   26       88         90   59500000.0  285000.0     2170
# 2      Coutinho   26       88         89   69500000.0  340000.0     2175
# 3       Marcelo   30       88         88   43000000.0  285000.0     2279
# 4  Thiago Silva   33       88         88   24000000.0  165000.0     2077
#
#    International Reputation  Weak Foot  Skill Moves  ...  Penalties  \
# 0                       5.0        5.0          5.0  ...       81.0
# 1                       3.0        3.0          2.0  ...       66.0
# 2                       3.0        4.0          5.0  ...       70.0
# 3                       4.0        4.0          5.0  ...       59.0
# 4                       4.0        3.0          2.0  ...       60.0
#
#    Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0       94.0     27.0            24.0           33.0       9.0         9.0
# 1       84.0     88.0            90.0           87.0      13.0        14.0
# 2       85.0     55.0            54.0           47.0      12.0         7.0
# 3       86.0     71.0            85.0           86.0      12.0         5.0
# 4       81.0     88.0            89.0           85.0       9.0        12.0
#
#    GKKicking  GKPositioning  GKReflexes
# 0       15.0           15.0        11.0
# 1       16.0           12.0        12.0
# 2        9.0           14.0         6.0
# 3        5.0            5.0         9.0
# 4        5.0            9.0        10.0
#
# [5 rows x 45 columns]

# %%
#Selecting players with an overall score above 80
Br_df = Br_df[Br_df.Overall > 80]

# %%
#Create a separate column for names
player_names= names = Br_df.Name.tolist() # saving names for later

Br_df = Br_df.drop(['Name'], axis = 1) # drop the name column so that the dataframe consists of only numeric values
Br_df.head()
# Out:
#    Age  Overall  Potential        Value      Wage  Special  \
# 0   26       92         93  118500000.0  290000.0     2143
# 1   26       88         90   59500000.0  285000.0     2170
# 2   26       88         89   69500000.0  340000.0     2175
# 3   30       88         88   43000000.0  285000.0     2279
# 4   33       88         88   24000000.0  165000.0     2077
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  ...  \
# 0                       5.0        5.0          5.0           10.0  ...
# 1                       3.0        3.0          2.0           14.0  ...
# 2                       3.0        4.0          5.0            7.0  ...
# 3                       4.0        4.0          5.0           12.0  ...
# 4                       4.0        3.0          2.0            2.0  ...
#
#    Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0       81.0       94.0     27.0            24.0           33.0       9.0
# 1       66.0       84.0     88.0            90.0           87.0      13.0
# 2       70.0       85.0     55.0            54.0           47.0      12.0
# 3       59.0       86.0     71.0            85.0           86.0      12.0
# 4       60.0       81.0     88.0            89.0           85.0       9.0
#
#    GKHandling  GKKicking  GKPositioning  GKReflexes
# 0         9.0       15.0           15.0        11.0
# 1        14.0       16.0           12.0        12.0
# 2         7.0        9.0           14.0         6.0
# 3         5.0        5.0            5.0         9.0
# 4        12.0        5.0            9.0        10.0
#
# [5 rows x 44 columns]

# %% [markdown]
# __K-Means__

# %%
#Normalizing the dataset

x = Br_df.values
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
X_norm = pd.DataFrame(x_scaled)

# %%
#Combined the many columns existing into 2 columns for comparing

pca = PCA(n_components = 2)
reduced = pd.DataFrame(pca.fit_transform(X_norm))
pca.explained_variance_ratio_
# Out:
# array([0.4564, 0.2278])

# %%
# Created 4 clusters for analysis
kmeans = KMeans(n_clusters=4)
kmeans = kmeans.fit(reduced)
labels = kmeans.predict(reduced)
centroid = kmeans.cluster_centers_
clusters = kmeans.labels_.tolist()

# %%
reduced['cluster'] = clusters
reduced['name'] = player_names
reduced.columns = ['x', 'y', 'cluster', 'name']
reduced.head()
# Out:
#           x         y  cluster          name
# 0 -1.063853  1.456394        3     Neymar Jr
# 1 -0.272155 -0.813229        2      Casemiro
# 2 -0.976583  0.860093        3      Coutinho
# 3 -1.034121 -0.237379        2       Marcelo
# 4 -0.129858 -0.929779        1  Thiago Silva

# %%
#Plotting

sns.set(style="white")

ax = sns.lmplot(x="x", y="y", hue='cluster', data = reduced, legend=False,
                   fit_reg=False, size = 10, scatter_kws={"s": 250})

texts = []
for x, y, s in zip(reduced.x, reduced.y, reduced.name):
    texts.append(plt.text(x, y, s))

ax.set(ylim=(-2, 2))
plt.tick_params(labelsize=15)
plt.xlabel("PC 1", fontsize = 20)
plt.ylabel("PC 2", fontsize = 20)

plt.show()
# Out:
# C:\Users\shrik\anaconda3\lib\site-packages\seaborn\regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# __Hierarchical Clustering__

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

np.set_printoptions (precision=4, suppress=True)
plt.figure(figsize=(10,3))
# %matplotlib inline

plt.figure(figsize=(10,14))
plt.title('Hierarchical Clustering Dendrogram with Average Linkage')

dendrogram = dendrogram(linkage(X_norm, method="average"), labels= names, leaf_font_size = 13, orientation='right')

# %% [markdown]
# ### Germany

# %%
#Reading in the datasets
Gr_df = pd.read_csv("https://raw.githubusercontent.com/Brianc482/731_Group_Project/main/Data/Germany_cleaned.csv")
Gr_df.head()
# Out:
#             Name  Age Nationality  Overall  Potential       Value      Wage  \
# 0       T. Kroos   28     Germany       90         90  76500000.0  355000.0
# 1  M. ter Stegen   26     Germany       89         92  58000000.0  240000.0
# 2       M. Neuer   32     Germany       89         89  38000000.0  130000.0
# 3     M. Hummels   29     Germany       88         88  46000000.0  160000.0
# 4        L. Sané   22     Germany       86         92  61000000.0  195000.0
#
#    Special Preferred Foot  International Reputation  ...  Composure  Marking  \
# 0     2190          Right                       4.0  ...       85.0     72.0
# 1     1328          Right                       3.0  ...       69.0     25.0
# 2     1473          Right                       5.0  ...       70.0     17.0
# 3     2038          Right                       4.0  ...       91.0     88.0
# 4     2090           Left                       2.0  ...       78.0     36.0
#
#   StandingTackle SlidingTackle GKDiving GKHandling  GKKicking GKPositioning  \
# 0           79.0          69.0     10.0       11.0       13.0           7.0
# 1           13.0          10.0     87.0       85.0       88.0          85.0
# 2           10.0          11.0     90.0       86.0       91.0          87.0
# 3           90.0          88.0     15.0        6.0       10.0           5.0
# 4           32.0          35.0      8.0       12.0        9.0           9.0
#
#   GKReflexes Release Clause
# 0       10.0        €156.8M
# 1       90.0        €123.3M
# 2       87.0         €62.7M
# 3        6.0         €75.9M
# 4       14.0        €125.1M
#
# [5 rows x 83 columns]

# %%
#Describing the dataset
Gr_df.describe()
# Out:
#                Age      Overall    Potential         Value           Wage  \
# count  1198.000000  1198.000000  1198.000000  1.198000e+03    1198.000000
# mean     24.338063    66.086811    71.699499  2.529307e+06    9639.398998
# std       4.243240     6.638976     5.760017  6.224263e+06   22121.375147
# min      17.000000    47.000000    57.000000  1.000000e+04    1000.000000
# 25%      21.000000    62.000000    68.000000  3.500000e+05    1000.000000
# 50%      24.000000    66.000000    71.000000  6.750000e+05    3000.000000
# 75%      27.000000    70.000000    75.000000  1.400000e+06    8000.000000
# max      39.000000    90.000000    92.000000  7.650000e+07  355000.000000
#
#            Special  International Reputation    Weak Foot  Skill Moves  \
# count  1198.000000                1198.00000  1198.000000  1198.000000
# mean   1566.782972                   1.13606     3.126043     2.273790
# std     288.120087                   0.44854     0.700857     0.742659
# min     788.000000                   0.00000     0.000000     0.000000
# 25%    1437.000000                   1.00000     3.000000     2.000000
# 50%    1606.000000                   1.00000     3.000000     2.000000
# 75%    1754.750000                   1.00000     3.000000     3.000000
# max    2203.000000                   5.00000     5.000000     5.000000
#
#        Jersey Number  ...    Penalties    Composure      Marking  \
# count    1198.000000  ...  1198.000000  1198.000000  1198.000000
# mean       19.176127  ...    45.561770    56.229549    46.964107
# std        11.519691  ...    15.477877    13.288140    20.732039
# min         0.000000  ...     0.000000     0.000000     0.000000
# 25%         9.000000  ...    36.000000    49.000000    29.000000
# 50%        19.000000  ...    47.000000    58.000000    53.000000
# 75%        28.000000  ...    57.000000    66.000000    64.000000
# max        90.000000  ...    90.000000    91.000000    88.000000
#
#        StandingTackle  SlidingTackle     GKDiving   GKHandling    GKKicking  \
# count     1198.000000    1198.000000  1198.000000  1198.000000  1198.000000
# mean        47.500835      45.090985    18.095993    17.722037    17.214524
# std         22.315492      22.190921    19.371364    18.284726    17.716836
# min          0.000000       0.000000     0.000000     0.000000     0.000000
# 25%         26.000000      22.000000     8.000000     9.000000     8.000000
# 50%         56.000000      53.000000    11.000000    11.000000    11.000000
# 75%         66.000000      64.000000    14.000000    14.000000    14.000000
# max         90.000000      88.000000    90.000000    86.000000    91.000000
#
#        GKPositioning   GKReflexes
# count    1198.000000  1198.000000
# mean       17.464107    18.128548
# std        18.271506    19.741568
# min         0.000000     0.000000
# 25%         8.000000     8.000000
# 50%        11.000000    11.000000
# 75%        14.000000    14.000000
# max        87.000000    90.000000
#
# [8 rows x 72 columns]

# %%
Gr_df = Gr_df[['Name','Age', 'Overall', 'Potential', 'Value', 'Wage', 'Special',
       'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number',
       'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']]

# %%
#Selecting players with an overall score above 80
Gr_df = Gr_df[Gr_df.Overall > 80]

# %%
#Create a separate column for names
player_names= names = Gr_df.Name.tolist() # saving names for later

Gr_df = Gr_df.drop(['Name'], axis = 1) # drop the name column so that the dataframe consists of only numeric values
Gr_df.head()
# Out:
#    Age  Overall  Potential       Value      Wage  Special  \
# 0   28       90         90  76500000.0  355000.0     2190
# 1   26       89         92  58000000.0  240000.0     1328
# 2   32       89         89  38000000.0  130000.0     1473
# 3   29       88         88  46000000.0  160000.0     2038
# 4   22       86         92  61000000.0  195000.0     2090
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  ...  \
# 0                       4.0        5.0          3.0            8.0  ...
# 1                       3.0        4.0          1.0           22.0  ...
# 2                       5.0        4.0          1.0            1.0  ...
# 3                       4.0        3.0          3.0            5.0  ...
# 4                       2.0        3.0          4.0           19.0  ...
#
#    Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0       73.0       85.0     72.0            79.0           69.0      10.0
# 1       25.0       69.0     25.0            13.0           10.0      87.0
# 2       47.0       70.0     17.0            10.0           11.0      90.0
# 3       68.0       91.0     88.0            90.0           88.0      15.0
# 4       71.0       78.0     36.0            32.0           35.0       8.0
#
#    GKHandling  GKKicking  GKPositioning  GKReflexes
# 0        11.0       13.0            7.0        10.0
# 1        85.0       88.0           85.0        90.0
# 2        86.0       91.0           87.0        87.0
# 3         6.0       10.0            5.0         6.0
# 4        12.0        9.0            9.0        14.0
#
# [5 rows x 44 columns]

# %% [markdown]
# __K-Means__

# %%
#Normalizing the dataset

x = Gr_df.values
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
X_norm = pd.DataFrame(x_scaled)

# %%
#Combined the many columns existing into 2 columns for comparing

pca = PCA(n_components = 2)
reduced = pd.DataFrame(pca.fit_transform(X_norm))
pca.explained_variance_ratio_
# Out:
# array([0.5832, 0.1736])

# %%
# Created 4 clusters for analysis
kmeans = KMeans(n_clusters=4)
kmeans = kmeans.fit(reduced)
labels = kmeans.predict(reduced)
centroid = kmeans.cluster_centers_
clusters = kmeans.labels_.tolist()

# %%
reduced['cluster'] = clusters
reduced['name'] = player_names
reduced.columns = ['x', 'y', 'cluster', 'name']
reduced.head()
# Out:
#           x         y  cluster           name
# 0 -1.232304 -0.225221        3       T. Kroos
# 1  3.124842 -0.532824        1  M. ter Stegen
# 2  2.789711 -0.630173        1       M. Neuer
# 3 -0.609770  0.733395        2     M. Hummels
# 4 -1.053347 -1.052096        0        L. Sané

# %%
#Plotting

sns.set(style="white")

ax = sns.lmplot(x="x", y="y", hue='cluster', data = reduced, legend=False,
                   fit_reg=False, size = 10, scatter_kws={"s": 250})

texts = []
for x, y, s in zip(reduced.x, reduced.y, reduced.name):
    texts.append(plt.text(x, y, s))

ax.set(ylim=(-2, 2))
plt.tick_params(labelsize=15)
plt.xlabel("PC 1", fontsize = 20)
plt.ylabel("PC 2", fontsize = 20)

plt.show()
# Out:
# C:\Users\shrik\anaconda3\lib\site-packages\seaborn\regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# __Hierarchical Clustering__

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

np.set_printoptions (precision=4, suppress=True)
plt.figure(figsize=(10,3))
# %matplotlib inline

plt.figure(figsize=(10,14))
plt.title('Hierarchical Clustering Dendrogram with Average Linkage')

dendrogram = dendrogram(linkage(X_norm, method="average"), labels= names, leaf_font_size = 13, orientation='right')

# %% [markdown]
# ### Spain

# %%
#Reading in the dataset
Sp_df = pd.read_csv("https://raw.githubusercontent.com/Brianc482/731_Group_Project/main/Data/Spain_cleaned.csv")
Sp_df.head()
# Out:
#               Name  Age Nationality  Overall  Potential       Value      Wage  \
# 0           De Gea   27       Spain       91         93  72000000.0  260000.0
# 1     Sergio Ramos   32       Spain       91         91  51000000.0  380000.0
# 2      David Silva   32       Spain       90         90  60000000.0  285000.0
# 3  Sergio Busquets   29       Spain       89         89  51500000.0  315000.0
# 4             Isco   26       Spain       88         91  73500000.0  315000.0
#
#    Special Preferred Foot  International Reputation  ...  Composure  Marking  \
# 0     1471          Right                       4.0  ...       68.0     15.0
# 1     2201          Right                       4.0  ...       82.0     87.0
# 2     2115           Left                       4.0  ...       93.0     59.0
# 3     2065          Right                       4.0  ...       90.0     90.0
# 4     2137          Right                       3.0  ...       86.0     60.0
#
#   StandingTackle SlidingTackle GKDiving GKHandling  GKKicking GKPositioning  \
# 0           21.0          13.0     90.0       85.0       87.0          88.0
# 1           92.0          91.0     11.0        8.0        9.0           7.0
# 2           53.0          29.0      6.0       15.0        7.0           6.0
# 3           86.0          80.0      5.0        8.0       13.0           9.0
# 4           64.0          51.0     10.0        8.0       12.0          15.0
#
#   GKReflexes Release Clause
# 0       94.0        €138.6M
# 1       11.0        €104.6M
# 2       12.0          €111M
# 3       13.0        €105.6M
# 4        6.0        €156.2M
#
# [5 rows x 83 columns]

# %%
#Describing the dataset
Sp_df.describe()
# Out:
#                Age      Overall    Potential         Value           Wage  \
# count  1072.000000  1072.000000  1072.000000  1.072000e+03    1072.000000
# mean     25.325560    69.698694    74.616604  4.390718e+06   16322.761194
# std       4.651373     6.494103     5.604905  7.698894e+06   33260.569385
# min      16.000000    51.000000    57.000000  6.000000e+04    1000.000000
# 25%      21.000000    65.000000    71.000000  6.250000e+05    3000.000000
# 50%      25.000000    69.000000    74.000000  1.200000e+06    6000.000000
# 75%      29.000000    74.000000    78.000000  5.000000e+06   17000.000000
# max      39.000000    91.000000    93.000000  7.350000e+07  380000.000000
#
#            Special  International Reputation    Weak Foot  Skill Moves  \
# count  1072.000000               1072.000000  1072.000000  1072.000000
# mean   1664.870336                  1.179104     3.001866     2.476679
# std     265.224562                  0.516409     0.544899     0.790594
# min     814.000000                  0.000000     0.000000     0.000000
# 25%    1537.750000                  1.000000     3.000000     2.000000
# 50%    1706.000000                  1.000000     3.000000     3.000000
# 75%    1846.500000                  1.000000     3.000000     3.000000
# max    2230.000000                  4.000000     5.000000     5.000000
#
#        Jersey Number  ...    Penalties    Composure      Marking  \
# count    1072.000000  ...  1072.000000  1072.000000  1072.000000
# mean       17.536381  ...    50.967351    60.612873    50.271455
# std        10.998454  ...    16.144072    11.083519    19.334203
# min         0.000000  ...     0.000000     0.000000     0.000000
# 25%         8.000000  ...    41.000000    54.000000    35.750000
# 50%        17.000000  ...    51.000000    61.000000    56.000000
# 75%        26.000000  ...    63.000000    68.000000    65.000000
# max        87.000000  ...    88.000000    93.000000    91.000000
#
#        StandingTackle  SlidingTackle     GKDiving   GKHandling    GKKicking  \
# count     1072.000000    1072.000000  1072.000000  1072.000000  1072.000000
# mean        50.402985      48.177239    16.795709    16.819963    16.392724
# std         22.839470      22.594843    18.495167    18.050563    17.228125
# min          0.000000       0.000000     0.000000     0.000000     0.000000
# 25%         28.000000      26.000000     8.000000     8.000000     8.000000
# 50%         60.000000      56.000000    11.000000    11.000000    11.000000
# 75%         69.000000      67.000000    14.000000    14.000000    14.000000
# max         92.000000      91.000000    90.000000    85.000000    87.000000
#
#        GKPositioning   GKReflexes
# count    1072.000000  1072.000000
# mean       16.687500    16.852612
# std        17.948321    18.567833
# min         0.000000     0.000000
# 25%         8.000000     8.000000
# 50%        11.000000    11.000000
# 75%        14.000000    14.000000
# max        88.000000    94.000000
#
# [8 rows x 72 columns]

# %%
Sp_df = Sp_df[['Name','Age', 'Overall', 'Potential', 'Value', 'Wage', 'Special',
       'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number',
       'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']]

# %%
#Selecting players with an overall score above 80
Sp_df = Sp_df[Sp_df.Overall > 80]

# %%
#Create a separate column for names
player_names= names = Sp_df.Name.tolist() # saving names for later

Sp_df = Sp_df.drop(['Name'], axis = 1) # drop the name column so that the dataframe consists of only numeric values
Sp_df.head()
# Out:
#    Age  Overall  Potential       Value      Wage  Special  \
# 0   27       91         93  72000000.0  260000.0     1471
# 1   32       91         91  51000000.0  380000.0     2201
# 2   32       90         90  60000000.0  285000.0     2115
# 3   29       89         89  51500000.0  315000.0     2065
# 4   26       88         91  73500000.0  315000.0     2137
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  ...  \
# 0                       4.0        3.0          1.0            1.0  ...
# 1                       4.0        3.0          3.0           15.0  ...
# 2                       4.0        2.0          4.0           21.0  ...
# 3                       4.0        3.0          3.0            5.0  ...
# 4                       3.0        3.0          4.0           22.0  ...
#
#    Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0       40.0       68.0     15.0            21.0           13.0      90.0
# 1       75.0       82.0     87.0            92.0           91.0      11.0
# 2       75.0       93.0     59.0            53.0           29.0       6.0
# 3       60.0       90.0     90.0            86.0           80.0       5.0
# 4       76.0       86.0     60.0            64.0           51.0      10.0
#
#    GKHandling  GKKicking  GKPositioning  GKReflexes
# 0        85.0       87.0           88.0        94.0
# 1         8.0        9.0            7.0        11.0
# 2        15.0        7.0            6.0        12.0
# 3         8.0       13.0            9.0        13.0
# 4         8.0       12.0           15.0         6.0
#
# [5 rows x 44 columns]

# %% [markdown]
# __K-Means__

# %%
#Normalizing the dataset

x = Sp_df.values
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
X_norm = pd.DataFrame(x_scaled)

# %%
#Combined the many columns existing into 2 columns for comparing

pca = PCA(n_components = 2)
reduced = pd.DataFrame(pca.fit_transform(X_norm))
pca.explained_variance_ratio_
# Out:
# array([0.5111, 0.153 ])

# %%
# Created 4 clusters for analysis
kmeans = KMeans(n_clusters=4)
kmeans = kmeans.fit(reduced)
labels = kmeans.predict(reduced)
centroid = kmeans.cluster_centers_
clusters = kmeans.labels_.tolist()

# %%
reduced['cluster'] = clusters
reduced['name'] = player_names
reduced.columns = ['x', 'y', 'cluster', 'name']
reduced.head()
# Out:
#           x         y  cluster             name
# 0  3.007182  0.102894        1           De Gea
# 1 -0.644418  1.236600        2     Sergio Ramos
# 2 -0.870866 -0.289938        3      David Silva
# 3 -0.483861  1.108650        2  Sergio Busquets
# 4 -0.841203 -0.115421        3             Isco

# %%
#Plotting

sns.set(style="white")

ax = sns.lmplot(x="x", y="y", hue='cluster', data = reduced, legend=False,
                   fit_reg=False, size = 10, scatter_kws={"s": 250})

texts = []
for x, y, s in zip(reduced.x, reduced.y, reduced.name):
    texts.append(plt.text(x, y, s))

ax.set(ylim=(-2, 2))
plt.tick_params(labelsize=15)
plt.xlabel("PC 1", fontsize = 20)
plt.ylabel("PC 2", fontsize = 20)

plt.show()
# Out:
# C:\Users\shrik\anaconda3\lib\site-packages\seaborn\regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# __Hierarchical Clustering__

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

np.set_printoptions (precision=4, suppress=True)
plt.figure(figsize=(10,3))
# %matplotlib inline

plt.figure(figsize=(10,14))
plt.title('Hierarchical Clustering Dendrogram with Average Linkage')

dendrogram = dendrogram(linkage(X_norm, method="average"), labels= names, leaf_font_size = 13, orientation='right')

# %% [markdown]
# ### Italy

# %%
#Reading in the dataset
It_df = pd.read_csv("https://raw.githubusercontent.com/Brianc482/731_Group_Project/main/Data/Italy_cleaned.csv")
It_df.head()
# Out:
#            Name  Age Nationality  Overall  Potential       Value      Wage  \
# 0  G. Chiellini   33       Italy       89         89  27000000.0  215000.0
# 1    L. Insigne   27       Italy       88         88  62000000.0  165000.0
# 2     G. Buffon   40       Italy       88         88   4000000.0   77000.0
# 3   C. Immobile   28       Italy       87         87  52000000.0  115000.0
# 4   M. Verratti   25       Italy       86         89  55000000.0  135000.0
#
#    Special Preferred Foot  International Reputation  ...  Composure  Marking  \
# 0     1841           Left                       4.0  ...       84.0     93.0
# 1     2017          Right                       3.0  ...       83.0     51.0
# 2     1334          Right                       4.0  ...       70.0     13.0
# 3     2009          Right                       3.0  ...       81.0     34.0
# 4     2149          Right                       3.0  ...       93.0     78.0
#
#   StandingTackle SlidingTackle GKDiving GKHandling  GKKicking GKPositioning  \
# 0           93.0          90.0      3.0        3.0        2.0           4.0
# 1           24.0          22.0      8.0        4.0       14.0           9.0
# 2           11.0          11.0     88.0       87.0       74.0          90.0
# 3           33.0          32.0      6.0        8.0       15.0          12.0
# 4           83.0          80.0     12.0       12.0       15.0          15.0
#
#   GKReflexes Release Clause
# 0        3.0         €44.6M
# 1       10.0        €105.4M
# 2       83.0          €7.4M
# 3        6.0         €88.4M
# 4       10.0        €105.9M
#
# [5 rows x 83 columns]

# %%
#Describing the dataset
It_df.describe()
# Out:
#               Age     Overall   Potential         Value           Wage  \
# count  702.000000  702.000000  702.000000  7.020000e+02     702.000000
# mean    25.928775   68.158120   72.690883  3.047571e+06   13478.632479
# std      4.837213    6.530675    6.107445  5.975033e+06   23222.092741
# min     17.000000   47.000000   53.000000  1.000000e+04    1000.000000
# 25%     22.000000   64.000000   68.000000  5.000000e+05    1000.000000
# 50%     26.000000   68.000000   72.000000  9.000000e+05    3000.000000
# 75%     29.000000   72.000000   76.000000  2.800000e+06   15000.000000
# max     40.000000   89.000000   93.000000  6.200000e+07  215000.000000
#
#            Special  International Reputation   Weak Foot  Skill Moves  \
# count   702.000000                702.000000  702.000000   702.000000
# mean   1604.572650                  1.202279    2.834758     2.386040
# std     288.763105                  0.488493    0.737068     0.820896
# min     731.000000                  0.000000    0.000000     0.000000
# 25%    1463.000000                  1.000000    2.000000     2.000000
# 50%    1650.000000                  1.000000    3.000000     2.000000
# 75%    1800.750000                  1.000000    3.000000     3.000000
# max    2253.000000                  4.000000    5.000000     5.000000
#
#        Jersey Number  ...   Penalties   Composure     Marking  StandingTackle  \
# count     702.000000  ...  702.000000  702.000000  702.000000      702.000000
# mean       21.009972  ...   48.182336   62.263533   48.948718       48.152422
# std        18.999622  ...   17.293912   10.921993   21.752798       23.642447
# min         0.000000  ...    0.000000    0.000000    0.000000        0.000000
# 25%         9.000000  ...   37.000000   57.000000   28.000000       22.000000
# 50%        18.000000  ...   51.000000   63.000000   57.000000       58.000000
# 75%        26.000000  ...   61.000000   70.000000   66.000000       68.000000
# max        99.000000  ...   92.000000   93.000000   94.000000       93.000000
#
#        SlidingTackle    GKDiving  GKHandling   GKKicking  GKPositioning  \
# count     702.000000  702.000000  702.000000  702.000000     702.000000
# mean       46.470085   17.311966   17.032764   16.411681      16.910256
# std        23.428127   19.808019   19.025632   17.542938      19.098713
# min         0.000000    0.000000    0.000000    0.000000       0.000000
# 25%        21.000000    8.000000    8.000000    7.000000       7.000000
# 50%        57.000000   11.000000   11.000000   10.000000      10.000000
# 75%        66.000000   14.000000   14.000000   14.000000      14.000000
# max        90.000000   88.000000   87.000000   76.000000      90.000000
#
#        GKReflexes
# count  702.000000
# mean    17.585470
# std     20.265723
# min      0.000000
# 25%      8.000000
# 50%     11.000000
# 75%     14.000000
# max     90.000000
#
# [8 rows x 72 columns]

# %%
It_df = It_df[['Name','Age', 'Overall', 'Potential', 'Value', 'Wage', 'Special',
       'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number',
       'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']]

# %%
#Selecting players with an overall score above 80
It_df = It_df[It_df.Overall > 80]

# %%
#Create a separate column for names
player_names= names = It_df.Name.tolist() # saving names for later

It_df = It_df.drop(['Name'], axis = 1) # drop the name column so that the dataframe consists of only numeric values
It_df.head()
# Out:
#    Age  Overall  Potential       Value      Wage  Special  \
# 0   33       89         89  27000000.0  215000.0     1841
# 1   27       88         88  62000000.0  165000.0     2017
# 2   40       88         88   4000000.0   77000.0     1334
# 3   28       87         87  52000000.0  115000.0     2009
# 4   25       86         89  55000000.0  135000.0     2149
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  ...  \
# 0                       4.0        3.0          2.0            3.0  ...
# 1                       3.0        3.0          4.0           10.0  ...
# 2                       4.0        2.0          1.0            1.0  ...
# 3                       3.0        4.0          3.0           17.0  ...
# 4                       3.0        4.0          4.0            6.0  ...
#
#    Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0       50.0       84.0     93.0            93.0           90.0       3.0
# 1       61.0       83.0     51.0            24.0           22.0       8.0
# 2       22.0       70.0     13.0            11.0           11.0      88.0
# 3       78.0       81.0     34.0            33.0           32.0       6.0
# 4       64.0       93.0     78.0            83.0           80.0      12.0
#
#    GKHandling  GKKicking  GKPositioning  GKReflexes
# 0         3.0        2.0            4.0         3.0
# 1         4.0       14.0            9.0        10.0
# 2        87.0       74.0           90.0        83.0
# 3         8.0       15.0           12.0         6.0
# 4        12.0       15.0           15.0        10.0
#
# [5 rows x 44 columns]

# %% [markdown]
# __K-Means__

# %%
#Normalizing the dataset

x = It_df.values
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
X_norm = pd.DataFrame(x_scaled)

# %%
#Combined the many columns existing into 2 columns for comparing

pca = PCA(n_components = 2)
reduced = pd.DataFrame(pca.fit_transform(X_norm))
pca.explained_variance_ratio_
# Out:
# array([0.6017, 0.1599])

# %%
# Created 4 clusters for analysis
kmeans = KMeans(n_clusters=4)
kmeans = kmeans.fit(reduced)
labels = kmeans.predict(reduced)
centroid = kmeans.cluster_centers_
clusters = kmeans.labels_.tolist()

# %%
reduced['cluster'] = clusters
reduced['name'] = player_names
reduced.columns = ['x', 'y', 'cluster', 'name']
reduced.head()
# Out:
#           x         y  cluster          name
# 0 -0.189829  1.730823        0  G. Chiellini
# 1 -1.089239 -0.947842        1    L. Insigne
# 2  2.921179 -0.021334        2     G. Buffon
# 3 -0.843840 -0.260048        3   C. Immobile
# 4 -1.100353  0.338830        3   M. Verratti

# %%
#Plotting

sns.set(style="white")

ax = sns.lmplot(x="x", y="y", hue='cluster', data = reduced, legend=False,
                   fit_reg=False, size = 10, scatter_kws={"s": 250})

texts = []
for x, y, s in zip(reduced.x, reduced.y, reduced.name):
    texts.append(plt.text(x, y, s))

ax.set(ylim=(-2, 2))
plt.tick_params(labelsize=15)
plt.xlabel("PC 1", fontsize = 20)
plt.ylabel("PC 2", fontsize = 20)

plt.show()
# Out:
# C:\Users\shrik\anaconda3\lib\site-packages\seaborn\regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# __Hierarchical Clustering__

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

np.set_printoptions (precision=4, suppress=True)
plt.figure(figsize=(10,3))
# %matplotlib inline

plt.figure(figsize=(10,14))
plt.title('Hierarchical Clustering Dendrogram with Average Linkage')

dendrogram = dendrogram(linkage(X_norm, method="average"), labels= names, leaf_font_size = 13, orientation='right')
